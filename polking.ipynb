# %% [markdown]
# # Análisis Cualitativo de Sistemas Lineales

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sympy import *
from sympy.matrices import *
init_printing()

# %%
x, y = np.meshgrid(np.linspace(-2, 2.5, 15),
                   np.linspace(-1, 1, 15))

u = y
v = -np.sin(x) - y

plt.quiver(x, y, u, v)

plt.show()

# %%
x, y = np.meshgrid(np.linspace(-2, 2.5, 15),
                   np.linspace(-1, 1, 15))

u = y
v = -np.cos(x) - 0.5 * y

plt.quiver(x, y, u, v)
x, y = np.meshgrid([-np.pi/2.0,],
                   [0,])


plt.show()

# %% [markdown]
# # Jacobiana

# %%
x, y, J = symbols('x y J')
from sympy.functions.elementary.trigonometric import cos

jacobian = Matrix([[diff(y, x), diff(y, y)],
     [diff(-cos(x) - 0.5 * y, x), diff(-cos(x) - 0.5 * y, y)]])
J = jacobian
J
# Out:
# ⎡  0      1  ⎤
# ⎢            ⎥
# ⎣sin(x)  -0.5⎦

# %% [markdown]
# # Lambdify para el quiver-plot

# %%
x,y,u,v = symbols('x y u v')
expr = (1 - x - y) * x
f = lambdify((u, v), expr.subs({x:(1/4)+u, y:(3/4)-v}), "numpy")

expr = (4 -7 * x - 3 * y) * y
g = lambdify((u, v), expr.subs({x:(1/4)+u, y:(3/4)-v}), "numpy")

i, j = np.meshgrid(np.linspace(-1, 1, 15),
                   np.linspace(-1, 1, 15))
u = f(i,j)
v = g(i,j)

plt.quiver(i, j, u, v)
plt.show()

# %%
plt.quiver?
